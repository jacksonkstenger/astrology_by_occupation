# %%
import pandas as pd

df = pd.read_csv('concat_occupation_urls.csv')
#https://famouspeople.astro-seek.com/filter_occupation/?narozeni_stat=&povolani=football-soccer-player&narozeni_stat=&pohlavi=&razeni=
#https://famouspeople.astro-seek.com/filter_occupation/?narozeni_stat=&povolani=children-of-celebrities&narozeni_stat=&pohlavi=&razeni=
#https://famouspeople.astro-seek.com/filter_occupation/?narozeni_stat=&povolani=twins-triplets&narozeni_stat=&pohlavi=&razeni=

# %%
df
# Out:
#                                                  urls                   names
# 0   https://famouspeople.astro-seek.com/filter_occ...             astrologers
# 1   https://famouspeople.astro-seek.com/filter_occ...                chemists
# 2   https://famouspeople.astro-seek.com/filter_occ...                   cooks
# 3   https://famouspeople.astro-seek.com/filter_occ...               diplomats
# 4   https://famouspeople.astro-seek.com/filter_occ...                 doctors
# 5   https://famouspeople.astro-seek.com/filter_occ...           entrepreneurs
# 6   https://famouspeople.astro-seek.com/filter_occ...          fashion-models
# 7   https://famouspeople.astro-seek.com/filter_occ...  journalists-publicists
# 8   https://famouspeople.astro-seek.com/filter_occ...                 lawyers
# 9   https://famouspeople.astro-seek.com/filter_occ...          mathematicians
# 10  https://famouspeople.astro-seek.com/filter_occ...            philosophers
# ...

# %%
#football-players at 32
#children-of-celebs at 62
#twins-multiples at 69
df.at[32, 'urls'] = 'https://famouspeople.astro-seek.com/filter_occupation/?narozeni_stat=&povolani=football-soccer-player&narozeni_stat=&pohlavi=&razeni='
df.at[62, 'urls'] = 'https://famouspeople.astro-seek.com/filter_occupation/?narozeni_stat=&povolani=children-of-celebrities&narozeni_stat=&pohlavi=&razeni='
df.at[69, 'urls'] = 'https://famouspeople.astro-seek.com/filter_occupation/?narozeni_stat=&povolani=twins-triplets&narozeni_stat=&pohlavi=&razeni='

# %%
df
# Out:
#                                                  urls                   names
# 0   https://famouspeople.astro-seek.com/filter_occ...             astrologers
# 1   https://famouspeople.astro-seek.com/filter_occ...                chemists
# 2   https://famouspeople.astro-seek.com/filter_occ...                   cooks
# 3   https://famouspeople.astro-seek.com/filter_occ...               diplomats
# 4   https://famouspeople.astro-seek.com/filter_occ...                 doctors
# 5   https://famouspeople.astro-seek.com/filter_occ...           entrepreneurs
# 6   https://famouspeople.astro-seek.com/filter_occ...          fashion-models
# 7   https://famouspeople.astro-seek.com/filter_occ...  journalists-publicists
# 8   https://famouspeople.astro-seek.com/filter_occ...                 lawyers
# 9   https://famouspeople.astro-seek.com/filter_occ...          mathematicians
# 10  https://famouspeople.astro-seek.com/filter_occ...            philosophers
# ...

# %%
#football-players at 32
#children-of-celebs at 62
#twins-multiples at 69


df.iloc[69]['urls']
# Out:
# 'https://famouspeople.astro-seek.com/filter_occupation/?narozeni_stat=&povolani=twins-triplets&narozeni_stat=&pohlavi=&razeni='

# %%
df.to_csv('cleaned_up_concat_occupation_urls.csv', index=False)
