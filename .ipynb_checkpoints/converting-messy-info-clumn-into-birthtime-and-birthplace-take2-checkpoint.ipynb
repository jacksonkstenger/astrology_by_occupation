# %%
import pandas as pd
import numpy as np
import re
import string

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

from flatlib.datetime import Datetime
from flatlib.geopos import GeoPos
from flatlib.chart import Chart
from flatlib import const

from timezonefinder import TimezoneFinder
from datetime import datetime
from pytz import timezone, utc

# %%
df = pd.read_csv('some-csvs-to-work-with/hi_its_philosophers_df.csv')

# %%
df.head()
# Out:
#                     name                                               info  \
# 0         Michael_Haneke  Gender:MaleDate of Birth:23 March  1942Birth p...
# 1           Noam_Chomsky  Gender:MaleDate of Birth:7 December  1928 - 07...
# 2           Albert_Camus  Gender:MaleDate of Birth:7 November  1913 - 02...
# 3         Mahatma_Gandhi  Gender:MaleDate of Birth:2 October  1869 - 07:...
# 4  Jean-Jacques_Rousseau  Gender:MaleDate of Birth:28 June  1712 - 10:00...
#
#        occupation
# 0  r_philosophers
# 1  r_philosophers
# 2  r_philosophers
# 3  r_philosophers
# 4  r_philosophers

# %%
copy_df = df
copy_df['count'] = np.arange(len(copy_df))

# %%
def adios_weird_characters(i):
    s = copy_df.iloc[i].info
    printable = set(string.printable)
    return ''.join(filter(lambda x: x in printable, s))

# %%
copy_df['info_norm'] = copy_df['count'].apply(adios_weird_characters)
#copy_df_mod = copy_df.drop(['info'], axis=1)
copy_df_mod = copy_df
copy_df_mod = copy_df_mod.drop(['info'], axis=1)
copy_df_mod = copy_df_mod.rename(columns={"info_norm": "info"})

# %%
copy_df_mod.head()
# Out:
#                     name      occupation  count  \
# 0         Michael_Haneke  r_philosophers      0
# 1           Noam_Chomsky  r_philosophers      1
# 2           Albert_Camus  r_philosophers      2
# 3         Mahatma_Gandhi  r_philosophers      3
# 4  Jean-Jacques_Rousseau  r_philosophers      4
#
#                                                 info
# 0  Gender:MaleDate of Birth:23 March  1942Birth p...
# 1  Gender:MaleDate of Birth:7 December  1928 - 07...
# 2  Gender:MaleDate of Birth:7 November  1913 - 02...
# 3  Gender:MaleDate of Birth:2 October  1869 - 07:...
# 4  Gender:MaleDate of Birth:28 June  1712 - 10:00...

# %%
def get_birthtime_info(row):
    b_info = copy_df_mod['info'][row]
    if '*' in b_info:
        return None
    if '(gregor.)' in b_info:
        #b_info_mod_time = [b_info_mod_time[0][:-9]]
        b_info = b_info.replace('(gregor.)','')
    elif 'h(gregor.' in b_info:
        #b_info_mod_time = b_info_mod_time[:-8]
        b_info = b_info.replace('(gregor.','')
    b_info_mod = ''
    if 'Gender:FemaleDate of Birth:' in b_info:
        b_info_mod = b_info.replace('Gender:FemaleDate of Birth:', '')
    elif 'Gender:MaleDate of Birth:' in b_info:
        b_info_mod = b_info.replace('Gender:MaleDate of Birth:', '')
    if 'Birth place:' in b_info_mod:
        b_info_mod = b_info_mod.split('Birth place:')
    elif 'Country:' in b_info_mod:
        b_info_mod = b_info_mod.split('Country:')
    b_info_mod_time = b_info_mod[0]
    
    b_info_mod_time = b_info_mod_time.split(' - ')
    #print(b_info_mod_time)
    #print('...end of get_birthtime_info')
    
    return b_info_mod_time

def get_birthplace_info(row):
    b_info = copy_df_mod['info'][row]
    if '*' in b_info:
        return None
    if '(gregor.)' in b_info:
        #b_info_mod_place = b_info_mod_place[:-9]
        b_info = b_info.replace('(gregor.)','')
    elif '(gregor.' in b_info:
        #b_info_mod_place = b_info_mod_place[:-8]
        b_info = b_info.replace('h(gregor.','')
    b_info_mod = ''
    if 'Gender:FemaleDate of Birth:' in b_info:
        b_info_mod = b_info.replace('Gender:FemaleDate of Birth:', '')
    elif 'Gender:MaleDate of Birth:' in b_info:
        b_info_mod = b_info.replace('Gender:MaleDate of Birth:', '')
    else:
        return None
    if 'Birth place:' in b_info_mod:
        b_info_mod = b_info_mod.split('Birth place:')
    elif 'Country:' in b_info_mod:
        b_info_mod = b_info_mod.split('Country:')
    b_info_mod_place = b_info_mod[1].split('Age:')
    b_info_mod_place = b_info_mod_place[0]
    b_info_mod_place = b_info_mod_place.split('Country:')
    #print(b_info_mod_place)
    #print('...end of get_birthplace_info')
    
    return b_info_mod_place

def convert_month_name_to_number(month):
    month = month.lower()
    if month == 'january':
        return 1
    elif month == 'february':
        return 1
    elif month == 'march':
        return 1
    elif month == 'april':
        return 1
    elif month == 'may':
        return 1
    elif month == 'june':
        return 1
    elif month == 'july':
        return 1
    elif month == 'august':
        return 1
    elif month == 'september':
        return 1
    elif month == 'october':
        return 1
    elif month == 'november':
        return 1
    elif month == 'december':
        return 1
    else:
        print('Not_a_month')
        return None

def time_formatter(time_lst):
    if time_lst == None:
        return None
    if len(time_lst) == 2:
        first = time_lst[0]
        month = " ".join(re.split("[^a-zA-Z]*", first))
        month = month.replace(' ', '')
        first = first.replace(' ', '')
        temp = first.split(month)
        day = temp[0]
        year = temp[1]
        time = time_lst[1]
        time = time[:-1]
        ans = [year, convert_month_name_to_number(month), day, time]
        print(ans)
        return ans
    elif len(time_lst) == 1:
        first = time_lst[0]
        month = " ".join(re.split("[^a-zA-Z]*", first))
        month = month.replace(' ', '')
        first = first.replace(' ', '')
        temp = first.split(month)
        day = temp[0]
        year = temp[1]
        ans = [year, convert_month_name_to_number(month), day]
        print(ans)
        return ans
    return 'No_time_info'
        
    
def place_formatter(place_lst):
    if place_lst == None:
        return None
    if len(place_lst) == 1:
        name = place_lst[0].split(', ')
        ans = name[1]
        return ans
    else:
        city_info = place_lst[0]
        country_info = place_lst[1]
        if ',' in city_info:
            city_info = city_info.split(', ')
        else:
            city_info = [city_info]
        if ',' in country_info:
            country_info = country_info.split(', ')
            country_info = country_info[1]
        if len(city_info) == 2:
            city = city_info[0]
            state = city_info[1]
        elif len(city_info) == 1:
            city = city_info[0]
            state = 'no_state'
        country = country_info
        if state == 'no_state':
            ans = [city, country]
            ans = ', '.join(ans)
        else:
            ans = [city, state, country]
            ans = ', '.join(ans)
        print(ans)
        return ans

def make_time_column(row):
    return time_formatter(get_birthtime_info(row))

def make_place_column(row):
    return place_formatter(get_birthplace_info(row))

# %%
copy_df_mod['birthtime'] = copy_df_mod['count'].apply(make_time_column)

'''
print(copy_df_mod.iloc[38].info)
print(get_birthtime_info(38))
print(copy_df_mod.iloc[30].info)
print(get_birthtime_info(30))
'''

copy_df_mod['birthplace'] = copy_df_mod['count'].apply(make_place_column)
'''
print(copy_df_mod.iloc[32].info)
print(get_birthplace_info(32))
print(place_formatter(get_birthplace_info(32)))
print(copy_df_mod.iloc[33].info)
print(get_birthplace_info(33))
print(place_formatter(get_birthplace_info(33)))
'''
# Out:
# ['1942', 1, '23']
# ['1928', 1, '7', '07:00']
# ['1913', 1, '7', '02:00']
# ['1869', 1, '2', '07:08']
# ['1712', 1, '28', '10:00']
# ['1713', 1, '5', '17:00']
# ['1724', 1, '22', '05:00']
# ['1744', 1, '25', '23:30']
# ['1813', 1, '5']
# ['1844', 1, '15', '10:00']
# ['1872', 1, '18', '17:45']
# ['1928', 1, '16', '12:15']
# ['1788', 1, '22', '12:00']
# ['1818', 1, '5', '02:00']
# ['1831', 1, '12', '02:17']
# ['1885', 1, '8', '08:00']
# ['1815', 1, '2', '16:00']
# ['1878', 1, '8', '06:58']
# ['1939', 1, '1', '10:55']
# ['1925', 1, '18', '02:45']
# ['1820', 1, '28', '21:00']
# ['1804', 1, '28', '01:30']
# ['1926', 1, '15', '07:30']
# ['1900', 1, '23', '19:30']
# ['1711', 1, '7']
# ['1868', 1, '24', '15:00']
# ['1870', 1, '31', '03:30']
# ['1891', 1, '12', '00:30']
# ['1861', 1, '25', '23:15']
# ['1889', 1, '12', '09:00']
# ['1880', 1, '3', '15:00']
# ['1861', 1, '6']
# ['1937', 1, '10']
# ['1948', 1, '16']
# ['1937', 1, '19', '16:30']
# ['1849', 1, '21']
# ['1646', 1, '1', '18:45']
# ['1632', 1, '24', '14:00']
# ['1564', 1, '26', '15:41']
# ['1596', 1, '31']
# ['1135', 1, '6', '12:57']
# ['1304', 1, '28', '04:33']
# ['1931', 1, '28', '17:00']
# ['1772', 1, '21', '10:45']
# ['1846', 1, '5', '07:30']
# ['1884', 1, '26', '11:00']
# ['1901', 1, '15', '21:15']
# ['1812', 1, '21', '17:00']
# ['1903', 1, '11', '05:30']
# ['1918', 1, '16', '04:30']
# ['1906', 1, '14', '21:15']
# ['1872', 1, '15', '05:00']
# ['1810', 1, '28', '09:00']
# ['1949', 1, '15', '00:02']
# ['1929', 1, '27', '07:00']
# ['1946', 1, '25', '03:00']
# ['1859', 1, '18', '09:05']
# ['1952', 1, '30', '17:00']
# ['1920', 1, '13', '12:10']
# ['1916', 1, '20', '07:00']
# ['1838', 1, '16', '12:00']
# ['1887', 1, '30', '23:00']
# ['1862', 1, '2', '10:30']
# ['1904', 1, '4', '09:00']
# ['1940', 1, '2', '17:00']
# ['1930', 1, '15', '08:30']
# ['1859', 1, '20', '09:52']
# ['1833', 1, '19', '20:00']
# ['1867', 1, '28', '17:00']
# ['1945', 1, '2', '22:00']
# ['1859', 1, '20', '17:42']
# ['1924', 1, '13', '23:00']
# ['1949', 1, '30', '01:15']
# ['1838', 1, '18', '11:00']
# ['1772', 1, '7', '06:00']
# ['1900', 1, '11', '08:45']
# ['1913', 1, '17', '19:00']
# ['1875', 1, '29', '23:00']
# ['1884', 1, '13', '12:00']
# ['1891', 1, '22', '11:00']
# ['1805', 1, '30', '22:45']
# ['1885', 1, '17', '01:30']
# ['1901', 1, '18', '15:00']
# ['1854', 1, '28', '17:00']
# ['1934', 1, '3', '14:00']
# ['1929', 1, '18', '20:00']
# ['1889', 1, '26', '11:30']
# ['1828', 1, '5', '00:26']
# ['1895', 1, '14', '12:30']
# ['1883', 1, '23', '14:30']
# ['1859', 1, '3', '12:00']
# ['1880', 1, '20', '21:55']
# ['1933', 1, '10', '23:15']
# ['1940', 1, '13', '18:36']
# ['1895', 1, '12', '00:30']
# ['1823', 1, '21', '14:00']
# ['1883', 1, '15', '10:00']
# ['1872', 1, '8', '09:42']
# ['1801', 1, '1', '10:00']
# ['1924', 1, '10', '00:15']
# ['1913', 1, '27', '02:15']
# ['1882', 1, '18', '13:00']
# ['1822', 1, '9', '19:00']
# ['1921', 1, '8', '04:00']
# ['1905', 1, '1', '11:00']
# ['1919', 1, '15', '08:00']
# ['1854', 1, '24', '13:00']
# ['1772', 1, '2', '06:00']
# ['1883', 1, '9', '20:35']
# ['1853', 1, '2', '13:00']
# ['1869', 1, '25', '11:00']
# ['1896', 1, '9', '00:45']
# ['1856', 1, '20', '11:33']
# ['1802', 1, '16', '23:33']
# ['1823', 1, '28', '06:00']
# ['1815', 1, '1', '14:00']
# ['1924', 1, '19', '07:00']
# ['1743', 1, '18', '01:30']
# ['1863', 1, '16', '21:00']
# ['1921', 1, '21', '05:20']
# ['1775', 1, '27', '03:15']
# ['1897', 1, '5', '00:15']
# ['1907', 1, '18', '23:55']
# ['1930', 1, '1', '06:00']
# ['1847', 1, '2', '22:00']
# ['1820', 1, '27', '23:59']
# ['1880', 1, '29', '18:40']
# ['1891', 1, '6', '05:30']
# ['1806', 1, '25', '06:00']
# ['1828', 1, '21', '16:00']
# ['1893', 1, '22', '06:00']
# ['1817', 1, '12', '21:00']
# ['1886', 1, '18', '20:30']
# ['1809', 1, '29', '01:00']
# ['1934', 1, '2', '20:00']
# ['1807', 1, '30', '08:00']
# ['1863', 1, '12', '06:33']
# ['1949', 1, '31', '22:30']
# ['1889', 1, '26', '20:30']
# ['1814', 1, '22', '04:00']
# ['1915', 1, '12']
# ['1952', 1, '4']
# ['1949', 1, '21']
# ['1930', 1, '20']
# ['1932', 1, '18']
# ['1948', 1, '5', '23:30']
# ['1912', 1, '27', '11:20']
# ['1911', 1, '1', '02:30']
# ['1890', 1, '9', '01:42']
# ['1899', 1, '8']
# ['1907', 1, '11', '20:00']
# ['1868', 1, '3', '15:00']
# ['1905', 1, '14', '04:00']
# ['1892', 1, '15', '22:30']
# ['1933', 1, '29', '03:05']
# ['1898', 1, '27']
# ['1891', 1, '18', '21:00']
# ['1826', 1, '4', '06:00']
# ['1874', 1, '28']
# ['1915', 1, '17', '22:00']
# ['1927', 1, '9', '20:11']
# ['1974', 1, '24', '23:40']
# ['1896', 1, '23', '19:30']
# ['1770', 1, '27']
# ['1915', 1, '22', '23:00']
# ['1888', 1, '21', '02:00']
# ['1859', 1, '6', '13:00']
# ['1948', 1, '6', '03:00']
# ['1867', 1, '19', '01:30']
# ['1882', 1, '8', '07:00']
# ['1950', 1, '24', '16:30']
# ['1880', 1, '27', '13:00']
# ['1909', 1, '13', '13:20']
# ['1917', 1, '12']
# ['1908', 1, '14', '23:00']
# ['1806', 1, '20']
# ['1873', 1, '4']
# ['1916', 1, '10', '06:15']
# ['1902', 1, '28']
# ['1897', 1, '27', '00:19']
# ['1813', 1, '23', '19:00']
# ['1895', 1, '15', '13:00']
# ['1806', 1, '14', '15:40']
# ['1913', 1, '27', '04:00']
# ['1874', 1, '9']
# ['1908', 1, '12', '20:30']
# ['1713', 1, '24', '01:00']
# ['1886', 1, '20', '00:30']
# ['1852', 1, '25', '16:30']
# ['1846', 1, '9', '17:45']
# ['1949', 1, '24']
# ['1953', 1, '15']
# ['1896', 1, '21']
# ['1903', 1, '3']
# ['1883', 1, '20']
# ['1756', 1, '3']
# ['1840', 1, '4']
# ['1907', 1, '1']
# ['1813', 1, '29']
# ['1907', 1, '11']
# ['1970', 1, '1']
# ['1933', 1, '21']
# ['1929', 1, '13']
# ['1859', 1, '8']
# ['1906', 1, '28']
# Munich, Germany
# Philadelphia, Pennsylvania, United States
# Mondovi, Algeria
# Porbandar, India
# Geneva, Switzerland
# Langres, France
# Knigsberg, Germany
# Mohrungen, Poland
# Copenhagen, Denmark
# Roecken, Germany
# Trelleck, Wales, United Kingdom
# Chicago, Illinois, United States
# Gdask, Poland
# Trier, Germany
# Ekaterinoslav, Dnipro, Ukraine
# Ludwigshafen, Germany
# Lincoln, England, United Kingdom
# Vienna, Austria
# Vienna, Austria
# Paris, France
# Wuppertal, Germany
# Landshut, Germany
# Poitiers, France
# Frankfurt, Germany
# Edinburgh, Scotland, United Kingdom
# Berlin, Germany
# Chiaravalle, Italy
# Hof, Germany
# Donji Kraljevec, Croatia
# Florence, Italy
# Vienna, Austria
# Kolkata, India
# Lnen, Germany
# Boulogne-Billancourt, France
# Bartelshagen, Germany
# Leipzig, Germany
# Amsterdam, Netherlands
# Pisa, Italy
# Descartes, France
# Crdoba, Spain
# Arezzo, Italy
# Paris, France
# Ottery St Mary, England, United Kingdom
# Aurich, Germany
# Bar-sur-Aube, France
# Salerno, Italy
# Bonn, Germany
# Frankfurt, Germany
# Bir Mourad Ras, Algeria
# Hanover, Germany
# Kolkata, India
# Vic, Spain
# Gtersloh, Germany
# Reims, France
# Toulouse, France
# Paris, France
# Aix-les-Bains, France
# Lbeck, Germany
# Saint-tienne, France
# Boppard, Germany
# London, England, United Kingdom
# Elizabeth, New Jersey, United States
# Castelnaudary, France
# Paris, France
# El Biar, Algeria
# Burlington, Vermont, United States
# Wiesbaden, Germany
# Bad Kreuznach, Germany
# Villeneuve-le-Roi, France
# Vienna, Austria
# Vienna, Austria
# Paris, France
# La Pouze, France
# Besanon, France
# Marburg, Germany
# Marseille, France
# Castelvetrano, Italy
# Paris, France
# Ales, Italy
# Lille, France
# Verona, Italy
# Saint-tienne, France
# Laval, France
# Mollendo, Peru
# Dsseldorf, Germany
# Messkirch, Germany
# Lorient, France
# Stuttgart, Germany
# Oldenburg, Germany
# Castres, France
# Knnu, Plva County, Estonia
# Ikaalinen, Finland
# Bay Shore, New York, United States
# Madanapalle, India
# Bguey, France
# Saint-Martin-de-Villeral, France
# Hanover, Germany
# Paris, France
# Versailles, France
# Oban, Scotland, United Kingdom
# Paris, France
# 's-Hertogenbosch, Netherlands
# Paris, France
# Grenoble, France
# Dublin, Ireland
# Dsseldorf, Germany
# Hettstedt, Germany
# Madrid, Spain
# Riga, Latvia
# Peine, Germany
# Neuchtel, Switzerland
# Edinburgh, Scotland, United Kingdom
# Lebanon, New Hampshire, United States
# Trguier, France
# Montpellier, France
# Marseille, France
# Amboise, France
# Madrid, Spain
# Jamalpur, India
# Leonberg, Germany
# Berlin, Germany
# Basel, Switzerland
# Agen, France
# Cherbourg-Octeville, France
# Derby, England, United Kingdom
# Blankenburg (Harz), Germany
# Vienna, Austria
# Bayreuth, Germany
# Vouziers, France
# Kobe, Japan
# Concord, Massachusetts, United States
# Foligno, Italy
# Torcenay, France
# Bruges, Belgium
# Ludwigsburg, Germany
# Kolkata, India
# Oklahoma City, Oklahoma, United States
# Vienna, Austria
# Kleinbottwar, Germany
# Cherbourg-Octeville, France
# Jejsk, Russia
# Ljubljana, Slovenia
# Prague, Czech Republic
# Prague, Czech Republic
# Bni Saf, Algeria
# Oslo, Norway
# Meythet, France
# Hradec Kralove, Czech Republic
# Vienna, Austria
# Toulouse, France
# Mortagne-au-Perche, France
# Paris, France
# Berlin, Germany
# Houston, Texas, United States
# London, England, United Kingdom
# Wuppertal, Germany
# Poitiers, France
# Wrocaw, Poland
# Ussel, France
# Grand Junction, Colorado, United States
# Thionville, France
# Frth, Germany
# Stuttgart, Germany
# Elgin, Scotland, United Kingdom
# Cowdenbeath, Scotland, United Kingdom
# Dresden, Germany
# Tel Aviv-Yafo, Israel
# Dijon, France
# Elbeuf, France
# Angers, France
# Dsseldorf, Germany
# Glasgow, Scotland, United Kingdom
# Dabalpur, India
# Rochefort, France
# London, England, United Kingdom
# Bromley, England, United Kingdom
# Dysart, Scotland, United Kingdom
# Vienna, Austria
# Basel, Switzerland
# Namur, Belgium
# Columbus, Ohio, United States
# Lyon, France
# Valence, France
# Saint Petersburg, Russia
# Giarre, Italy
# Majorca, Spain
# Starosiedle, Poland
# hringen, Germany
# Gppingen, Germany
# Krakw, Poland
# Rakovnk, Czech Republic
# Prague, Czech Republic
# Sobslav, Czech Republic
# Koln, Czech Republic
# Wisbech, England, United Kingdom
# Metnov, Czech Republic
# Turnov, Czech Republic
# Prague, Czech Republic
# Prostjov, Czech Republic
# Seville, Spain
# Prague, Czech Republic
# Prague, Czech Republic
# Prostjov, Czech Republic
# Brno, Czech Republic
# '\nprint(copy_df_mod.iloc[32].info)\nprint(get_birthplace_info(32))\nprint(place_formatter(get_birthplace_info(32)))\nprint(copy_df_mod.iloc[33].info)\nprint(get_birthplace_info(33))\nprint(place_formatter(get_birthplace_info(33)))\n'

# %%
copy_df_mod.head(100)
# Out:
#                        name      occupation  count  \
# 0            Michael_Haneke  r_philosophers      0
# 1              Noam_Chomsky  r_philosophers      1
# 2              Albert_Camus  r_philosophers      2
# 3            Mahatma_Gandhi  r_philosophers      3
# 4     Jean-Jacques_Rousseau  r_philosophers      4
# 5             Denis_Diderot  r_philosophers      5
# 6             Immanuel_Kant  r_philosophers      6
# 7   Johann_Gottfried_Herder  r_philosophers      7
# 8        Soeren_Kierkegaard  r_philosophers      8
# 9       Friedrich_Nietzsche  r_philosophers      9
# 10         Bertrand_Russell  r_philosophers     10
# 11           Philip_K._Dick  r_philosophers     11
# 12      Arthur_Schopenhauer  r_philosophers     12
# 13                Karl_Marx  r_philosophers     13
# 14         Helena_Blavatsky  r_philosophers     14
# 15              Ernst_Bloch  r_philosophers     15
# 16             George_Boole  r_philosophers     16
# 17             Martin_Buber  r_philosophers     17
# 18            Fritjof_Capra  r_philosophers     18
# 19           Gilles_Deleuze  r_philosophers     19
# 20         Friedrich_Engels  r_philosophers     20
# 21         Ludwig_Feuerbach  r_philosophers     21
# 22          Michel_Foucault  r_philosophers     22
# 23              Erich_Fromm  r_philosophers     23
# 24               David_Hume  r_philosophers     24
# 25          Emmanuel_Lasker  r_philosophers     25
# 26         Maria_Montessori  r_philosophers     26
# 27         Teresa_Benedicta  r_philosophers     27
# 28           Rudolf_Steiner  r_philosophers     28
# 29  Dietrich_von_Hildebrand  r_philosophers     29
# ..                      ...             ...    ...
# 70      Christian_Ehrenfels  r_philosophers     70
# 71          Paul_Feyerabend  r_philosophers     71
# 72       Alain_Finkielkraut  r_philosophers     72
# 73          Alfred_Fouillée  r_philosophers     73
# 74          Charles_Fourier  r_philosophers     74
# 75       Hans-Georg_Gadamer  r_philosophers     75
# 76            Roger_Garaudy  r_philosophers     76
# 77         Giovanni_Gentile  r_philosophers     77
# 78           Etienne_Gilson  r_philosophers     78
# 79          Antonio_Gramsci  r_philosophers     79
# 80            Joseph_Gratry  r_philosophers     80
# 81          Romano_Guardini  r_philosophers     81
# 82             Jean_Guitton  r_philosophers     82
# 83         Jean-Marie_Guyau  r_philosophers     83
# 84           Abimael_Guzman  r_philosophers     84
# 85          Jürgen_Habermas  r_philosophers     85
# 86         Martin_Heidegger  r_philosophers     86
# 87             Ernest_Hello  r_philosophers     87
# 88           Max_Horkheimer  r_philosophers     88
# 89             Karl_Jaspers  r_philosophers     89
# 90              Jean_Jaurès  r_philosophers     90
# 91   Hermann_Von_Keyserling  r_philosophers     91
# 92        S._Albert_Kivinen  r_philosophers     92
# 93              Saul_Kripke  r_philosophers     93
# 94       Jiddu_Krishnamurti  r_philosophers     94
# 95          Pierre_Laffitte  r_philosophers     95
# 96            Louis_Lavelle  r_philosophers     96
# 97          Theodor_Lessing  r_philosophers     97
# 98             Émile_Littré  r_philosophers     98
# 99    Jean-François_Lyotard  r_philosophers     99
#
#                                                  info             birthtime  \
# 0   Gender:MaleDate of Birth:23 March  1942Birth p...         [1942, 1, 23]
# 1   Gender:MaleDate of Birth:7 December  1928 - 07...   [1928, 1, 7, 07:00]
# 2   Gender:MaleDate of Birth:7 November  1913 - 02...   [1913, 1, 7, 02:00]
# 3   Gender:MaleDate of Birth:2 October  1869 - 07:...   [1869, 1, 2, 07:08]
# 4   Gender:MaleDate of Birth:28 June  1712 - 10:00...  [1712, 1, 28, 10:00]
# 5   Gender:MaleDate of Birth:5 October  1713 - 17:...   [1713, 1, 5, 17:00]
# 6   Gender:MaleDate of Birth:22 April  1724 - 05:0...  [1724, 1, 22, 05:00]
# 7   Gender:MaleDate of Birth:25 August  1744 - 23:...  [1744, 1, 25, 23:30]
# 8   Gender:MaleDate of Birth:5 May  1813Birth plac...          [1813, 1, 5]
# 9   Gender:MaleDate of Birth:15 October  1844 - 10...  [1844, 1, 15, 10:00]
# 10  Gender:MaleDate of Birth:18 May  1872 - 17:45h...  [1872, 1, 18, 17:45]
# 11  Gender:MaleDate of Birth:16 December  1928 - 1...  [1928, 1, 16, 12:15]
# 12  Gender:MaleDate of Birth:22 February  1788 - 1...  [1788, 1, 22, 12:00]
# 13  Gender:MaleDate of Birth:5 May  1818 - 02:00hB...   [1818, 1, 5, 02:00]
# 14  Gender:FemaleDate of Birth:12 August  1831 - 0...  [1831, 1, 12, 02:17]
# 15  Gender:MaleDate of Birth:8 July  1885 - 08:00h...   [1885, 1, 8, 08:00]
# 16  Gender:MaleDate of Birth:2 November  1815 - 16...   [1815, 1, 2, 16:00]
# 17  Gender:MaleDate of Birth:8 February  1878 - 06...   [1878, 1, 8, 06:58]
# 18  Gender:MaleDate of Birth:1 February  1939 - 10...   [1939, 1, 1, 10:55]
# 19  Gender:MaleDate of Birth:18 January  1925 - 02...  [1925, 1, 18, 02:45]
# 20  Gender:MaleDate of Birth:28 November  1820 - 2...  [1820, 1, 28, 21:00]
# 21  Gender:MaleDate of Birth:28 July  1804 - 01:30...  [1804, 1, 28, 01:30]
# 22  Gender:MaleDate of Birth:15 October  1926 - 07...  [1926, 1, 15, 07:30]
# 23  Gender:MaleDate of Birth:23 March  1900 - 19:3...  [1900, 1, 23, 19:30]
# 24  Gender:MaleDate of Birth:7 May  1711(gregor.)B...          [1711, 1, 7]
# 25  Gender:MaleDate of Birth:24 December  1868 - 1...  [1868, 1, 24, 15:00]
# 26  Gender:FemaleDate of Birth:31 August  1870 - 0...  [1870, 1, 31, 03:30]
# 27  Gender:FemaleDate of Birth:12 October  1891 - ...  [1891, 1, 12, 00:30]
# 28  Gender:MaleDate of Birth:25 February  1861 - 2...  [1861, 1, 25, 23:15]
# 29  Gender:MaleDate of Birth:12 October  1889 - 09...  [1889, 1, 12, 09:00]
# ..                                                ...                   ...
# 70  Gender:MaleDate of Birth:20 June  1859 - 17:42...  [1859, 1, 20, 17:42]
# 71  Gender:MaleDate of Birth:13 January  1924 - 23...  [1924, 1, 13, 23:00]
# 72  Gender:MaleDate of Birth:30 June  1949 - 01:15...  [1949, 1, 30, 01:15]
# 73  Gender:MaleDate of Birth:18 October  1838 - 11...  [1838, 1, 18, 11:00]
# 74  Gender:MaleDate of Birth:7 April  1772 - 06:00...   [1772, 1, 7, 06:00]
# 75  Gender:MaleDate of Birth:11 February  1900 - 0...  [1900, 1, 11, 08:45]
# 76  Gender:MaleDate of Birth:17 July  1913 - 19:00...  [1913, 1, 17, 19:00]
# 77  Gender:MaleDate of Birth:29 May  1875 - 23:00h...  [1875, 1, 29, 23:00]
# 78  Gender:MaleDate of Birth:13 June  1884 - 12:00...  [1884, 1, 13, 12:00]
# 79  Gender:MaleDate of Birth:22 January  1891 - 11...  [1891, 1, 22, 11:00]
# 80  Gender:MaleDate of Birth:30 March  1805 - 22:4...  [1805, 1, 30, 22:45]
# 81  Gender:MaleDate of Birth:17 February  1885 - 0...  [1885, 1, 17, 01:30]
# 82  Gender:MaleDate of Birth:18 August  1901 - 15:...  [1901, 1, 18, 15:00]
# 83  Gender:MaleDate of Birth:28 October  1854 - 17...  [1854, 1, 28, 17:00]
# 84  Gender:MaleDate of Birth:3 December  1934 - 14...   [1934, 1, 3, 14:00]
# 85  Gender:MaleDate of Birth:18 June  1929 - 20:00...  [1929, 1, 18, 20:00]
# 86  Gender:MaleDate of Birth:26 September  1889 - ...  [1889, 1, 26, 11:30]
# 87  Gender:MaleDate of Birth:5 November  1828 - 00...   [1828, 1, 5, 00:26]
# 88  Gender:MaleDate of Birth:14 February  1895 - 1...  [1895, 1, 14, 12:30]
# 89  Gender:MaleDate of Birth:23 February  1883 - 1...  [1883, 1, 23, 14:30]
# 90  Gender:MaleDate of Birth:3 September  1859 - 1...   [1859, 1, 3, 12:00]
# 91  Gender:MaleDate of Birth:20 July  1880 - 21:55...  [1880, 1, 20, 21:55]
# 92  Gender:MaleDate of Birth:10 October  1933 - 23...  [1933, 1, 10, 23:15]
# 93  Gender:MaleDate of Birth:13 November  1940 - 1...  [1940, 1, 13, 18:36]
# 94  Gender:MaleDate of Birth:12 May  1895 - 00:30h...  [1895, 1, 12, 00:30]
# 95  Gender:MaleDate of Birth:21 February  1823 - 1...  [1823, 1, 21, 14:00]
# 96  Gender:MaleDate of Birth:15 July  1883 - 10:00...  [1883, 1, 15, 10:00]
# 97  Gender:MaleDate of Birth:8 February  1872 - 09...   [1872, 1, 8, 09:42]
# 98  Gender:MaleDate of Birth:1 February  1801 - 10...   [1801, 1, 1, 10:00]
# 99  Gender:MaleDate of Birth:10 August  1924 - 00:...  [1924, 1, 10, 00:15]
#
#                                    birthplace
# 0                             Munich, Germany
# 1   Philadelphia, Pennsylvania, United States
# 2                            Mondovi, Algeria
# 3                            Porbandar, India
# 4                         Geneva, Switzerland
# 5                             Langres, France
# 6                          Knigsberg, Germany
# 7                           Mohrungen, Poland
# 8                         Copenhagen, Denmark
# 9                            Roecken, Germany
# 10            Trelleck, Wales, United Kingdom
# 11           Chicago, Illinois, United States
# 12                              Gdask, Poland
# 13                             Trier, Germany
# 14             Ekaterinoslav, Dnipro, Ukraine
# 15                      Ludwigshafen, Germany
# 16           Lincoln, England, United Kingdom
# 17                            Vienna, Austria
# 18                            Vienna, Austria
# 19                              Paris, France
# 20                         Wuppertal, Germany
# 21                          Landshut, Germany
# 22                           Poitiers, France
# 23                         Frankfurt, Germany
# 24        Edinburgh, Scotland, United Kingdom
# 25                            Berlin, Germany
# 26                         Chiaravalle, Italy
# 27                               Hof, Germany
# 28                   Donji Kraljevec, Croatia
# 29                            Florence, Italy
# ..                                        ...
# 70                            Vienna, Austria
# 71                            Vienna, Austria
# 72                              Paris, France
# 73                           La Pouze, France
# 74                            Besanon, France
# 75                           Marburg, Germany
# 76                          Marseille, France
# 77                       Castelvetrano, Italy
# 78                              Paris, France
# 79                                Ales, Italy
# 80                              Lille, France
# 81                              Verona, Italy
# 82                       Saint-tienne, France
# 83                              Laval, France
# 84                             Mollendo, Peru
# 85                         Dsseldorf, Germany
# 86                         Messkirch, Germany
# 87                            Lorient, France
# 88                         Stuttgart, Germany
# 89                         Oldenburg, Germany
# 90                            Castres, France
# 91                 Knnu, Plva County, Estonia
# 92                         Ikaalinen, Finland
# 93         Bay Shore, New York, United States
# 94                         Madanapalle, India
# 95                              Bguey, France
# 96           Saint-Martin-de-Villeral, France
# 97                           Hanover, Germany
# 98                              Paris, France
# 99                         Versailles, France
#
# [100 rows x 6 columns]

# %%
strngstrng = '''
Munich, Germany
Philadelphia, Pennsylvania, United States
Mondovi, Algeria
Porbandar, India
Geneva, Switzerland
Langres, France
Knigsberg, Germany
Mohrungen, Poland
Copenhagen, Denmark
Roecken, Germany
Trelleck, Wales, United Kingdom
Chicago, Illinois, United States
Gdask, Poland
Trier, Germany
Ekaterinoslav, Dnipro, Ukraine
Ludwigshafen, Germany
Lincoln, England, United Kingdom
Vienna, Austria
Vienna, Austria
Paris, France
Wuppertal, Germany
Landshut, Germany
Poitiers, France
Frankfurt, Germany
Edinburgh, Scotland, United Kingdom
Berlin, Germany
Chiaravalle, Italy
Hof, Germany
Donji Kraljevec, Croatia
Florence, Italy
Vienna, Austria
Kolkata, India
'''
counttemptemp = 0
for e in strngstrng:
    if e == '\n':
        counttemptemp += 1
print(counttemptemp)
# Out:
# 33

# %%
best_df_ever = copy_df_mod.drop(['info'], axis=1)

# %%
best_df_ever.head(15)
# Out:
#                        name      occupation  count             birthtime  \
# 0            Michael_Haneke  r_philosophers      0         [1942, 1, 23]
# 1              Noam_Chomsky  r_philosophers      1   [1928, 1, 7, 07:00]
# 2              Albert_Camus  r_philosophers      2   [1913, 1, 7, 02:00]
# 3            Mahatma_Gandhi  r_philosophers      3   [1869, 1, 2, 07:08]
# 4     Jean-Jacques_Rousseau  r_philosophers      4  [1712, 1, 28, 10:00]
# 5             Denis_Diderot  r_philosophers      5   [1713, 1, 5, 17:00]
# 6             Immanuel_Kant  r_philosophers      6  [1724, 1, 22, 05:00]
# 7   Johann_Gottfried_Herder  r_philosophers      7  [1744, 1, 25, 23:30]
# 8        Soeren_Kierkegaard  r_philosophers      8          [1813, 1, 5]
# 9       Friedrich_Nietzsche  r_philosophers      9  [1844, 1, 15, 10:00]
# 10         Bertrand_Russell  r_philosophers     10  [1872, 1, 18, 17:45]
# 11           Philip_K._Dick  r_philosophers     11  [1928, 1, 16, 12:15]
# 12      Arthur_Schopenhauer  r_philosophers     12  [1788, 1, 22, 12:00]
# 13                Karl_Marx  r_philosophers     13   [1818, 1, 5, 02:00]
# 14         Helena_Blavatsky  r_philosophers     14  [1831, 1, 12, 02:17]
#
#                                    birthplace
# 0                             Munich, Germany
# 1   Philadelphia, Pennsylvania, United States
# 2                            Mondovi, Algeria
# 3                            Porbandar, India
# 4                         Geneva, Switzerland
# 5                             Langres, France
# 6                          Knigsberg, Germany
# 7                           Mohrungen, Poland
# 8                         Copenhagen, Denmark
# 9                            Roecken, Germany
# 10            Trelleck, Wales, United Kingdom
# 11           Chicago, Illinois, United States
# 12                              Gdask, Poland
# 13                             Trier, Germany
# 14             Ekaterinoslav, Dnipro, Ukraine

# %%
geolocator = Nominatim(user_agent="specify_your_app_name_here")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
best_df_ever['location'] = best_df_ever['birthplace'].apply(geocode)
best_df_ever['point'] = best_df_ever['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('France',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Marburg, Germany',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Ales, Italy',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Knnu, Plva County, Estonia',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Bayreuth, Germany',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Prague, Czech Republic',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Wisbech, England, United Kingdom',), **{}).
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1317, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/anaconda3/lib/python3.7/http/client.py", line 1229, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1275, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1224, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/anaconda3/lib/python3.7/http/client.py", line 1016, in _send_output
#     self.send(msg)
#   File "/anaconda3/lib/python3.7/http/client.py", line 956, in send
#     self.connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 1384, in connect
#     super().connect()
#   File "/anaconda3/lib/python3.7/http/client.py", line 928, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "/anaconda3/lib/python3.7/socket.py", line 727, in create_connection
#     raise err
#   File "/anaconda3/lib/python3.7/socket.py", line 716, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 355, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 543, in _open
#     '_open', req)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1360, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "/anaconda3/lib/python3.7/urllib/request.py", line 1319, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/geopy/extra/rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py", line 406, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 378, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out

# %%
best_df_ever.tail(25)
# Out:
#                          name      occupation  count             birthtime  \
# 188          Nicholas_Roerich  r_philosophers    188          [1874, 1, 9]
# 189  Michele_Federico_Sciacca  r_philosophers    189  [1908, 1, 12, 20:30]
# 190            Junípero_Serra  r_philosophers    190  [1713, 1, 24, 01:00]
# 191              Paul_Tillich  r_philosophers    191  [1886, 1, 20, 00:30]
# 192        Johannes_Vaihinger  r_philosophers    192  [1852, 1, 25, 16:30]
# 193          Theobold_Ziegler  r_philosophers    193   [1846, 1, 9, 17:45]
# 194    Ryszard_Antoni_Legutko  r_philosophers    194         [1949, 1, 24]
# 195         Miloslav_Ransdorf  r_philosophers    195         [1953, 1, 15]
# 196         Karel_Josef_Beneš  r_philosophers    196         [1896, 1, 21]
# 197              Karel_Bodlák  r_philosophers    197          [1903, 1, 3]
# 198            Otokar_Fischer  r_philosophers    198         [1883, 1, 20]
# 199            William_Godwin  r_philosophers    199          [1756, 1, 3]
# 200     Jakub_Hron_Metánovský  r_philosophers    200          [1840, 1, 4]
# 201               Jan_Patočka  r_philosophers    201          [1907, 1, 1]
# 202              Karel_Sabina  r_philosophers    202         [1813, 1, 29]
# 203               Emil_Sedmík  r_philosophers    203                  None
# 204             Josef_Šafařík  r_philosophers    204         [1907, 1, 11]
# 205             Milan_Šimečka  r_philosophers    205                  None
# 206         Stanislav_Komárek  r_philosophers    206                  None
# 207              Paco_Vidarte  r_philosophers    207          [1970, 1, 1]
# 208           Ernst_Tugendhat  r_philosophers    208                  None
# 209              Erazim_Kohák  r_philosophers    209         [1933, 1, 21]
# 210           Ladislav_Menzel  r_philosophers    210         [1929, 1, 13]
# 211            Edmund_Husserl  r_philosophers    211          [1859, 1, 8]
# 212                Kurt_Gödel  r_philosophers    212         [1906, 1, 28]
#
#                            birthplace  \
# 188          Saint Petersburg, Russia
# 189                     Giarre, Italy
# 190                    Majorca, Spain
# 191               Starosiedle, Poland
# 192                  hringen, Germany
# 193                 Gppingen, Germany
# 194                     Krakw, Poland
# 195           Rakovnk, Czech Republic
# 196            Prague, Czech Republic
# 197           Sobslav, Czech Republic
# 198              Koln, Czech Republic
# 199  Wisbech, England, United Kingdom
# 200            Metnov, Czech Republic
# 201            Turnov, Czech Republic
# 202            Prague, Czech Republic
# 203                              None
# 204          Prostjov, Czech Republic
# 205                              None
# 206                              None
# 207                    Seville, Spain
# 208                              None
# 209            Prague, Czech Republic
# 210            Prague, Czech Republic
# 211          Prostjov, Czech Republic
# 212              Brno, Czech Republic
#
#                                               location  \
# 188  (Санкт-Петербург, Северо-Западный федеральный ...
# 189  (Giarre, Catania, Sicilia, 95014, Italia, (37....
# 190  (Mallorca, Sencelles, Pla de Mallorca, Illes B...
# 191  (Starosiedle, gmina Gubin, powiat krośnieński,...
# 192                                               None
# 193                                               None
# 194                                               None
# 195                                               None
# 196  (Praha, okres Hlavní město Praha, Hlavní město...
# 197                                               None
# 198                                               None
# 199  (Wisbech, Cambridgeshire, East of England, Eng...
# 200                                               None
# 201  (Turnov, okres Semily, Liberecký kraj, Severov...
# 202  (Praha, okres Hlavní město Praha, Hlavní město...
# 203  (None, Torino, Piemonte, Italia, (44.933143, 7...
# 204                                               None
# 205  (None, Torino, Piemonte, Italia, (44.933143, 7...
# 206  (None, Torino, Piemonte, Italia, (44.933143, 7...
# 207  (Sevilla, Andalucía, España, (37.3886303, -5.9...
# 208  (None, Torino, Piemonte, Italia, (44.933143, 7...
# 209  (Praha, okres Hlavní město Praha, Hlavní město...
# 210  (Praha, okres Hlavní město Praha, Hlavní město...
# 211                                               None
# 212  (Brno, okres Brno-město, Jihomoravský kraj, Ji...
#
#                                      point
# 188          (59.9606739, 30.1586551, 0.0)
# 189            (37.726857, 15.187688, 0.0)
# 190  (39.6134018, 2.8804305326400756, 0.0)
# 191           (51.8581096, 14.820994, 0.0)
# 192                                   None
# 193                                   None
# 194                                   None
# 195                                   None
# 196          (50.0874654, 14.4212535, 0.0)
# 197                                   None
# 198                                   None
# 199           (52.6651733, 0.1606824, 0.0)
# 200                                   None
# 201  (50.5872282, 15.150259702715726, 0.0)
# 202          (50.0874654, 14.4212535, 0.0)
# 203             (44.933143, 7.540121, 0.0)
# 204                                   None
# 205             (44.933143, 7.540121, 0.0)
# 206             (44.933143, 7.540121, 0.0)
# 207          (37.3886303, -5.9953403, 0.0)
# 208             (44.933143, 7.540121, 0.0)
# 209          (50.0874654, 14.4212535, 0.0)
# 210          (50.0874654, 14.4212535, 0.0)
# 211                                   None
# 212          (49.1922443, 16.6113382, 0.0)

# %% [markdown]
# This seems to work. We will perform this process on every occupation dataframe that we have.
#
# But before we run a for loop on all our dataframes, let's continue with this specific data frame.
#
# Let's feed our dataframe into FlatLib, get some results, analyze the results, and add these results to our dataframe as a set of columns.
#
# I'm gonna use an np.array.

# %% [markdown]
# Ehhh... let's just stick to Pandas, it'll be just as direct.

# %%
#OLD CODE

'''
date = Datetime('1997/07/02', '16:07', '-07:00')
#date.jd
print(date.jd)

pos = GeoPos('37n7644', '121w9540')
print(pos.lat,pos.lon)

chart = Chart(date, pos)
'''
print('hi')
# Out:
# hi

# %%
jackson_df = pd.DataFrame([['Jackson_Stenger','r_philosopher',0,[1997, 7, 2],'San Ramon, California, United States']], columns = ['name', 'occupation', 'count', 'birthtime', 'birthplace'])

# %%
jackson_df.head()
# Out:
#               name     occupation  count     birthtime  \
# 0  Jackson_Stenger  r_philosopher      0  [1997, 7, 2]
#
#                              birthplace
# 0  San Ramon, California, United States

# %%
geolocator1 = Nominatim(user_agent="specify_your_app_name_here")
geocode1 = RateLimiter(geolocator1.geocode, min_delay_seconds=1)
jackson_df['location'] = jackson_df['birthplace'].apply(geocode1)
jackson_df['point'] = jackson_df['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
jackson_df
# Out:
#               name     occupation  count     birthtime  \
# 0  Jackson_Stenger  r_philosopher      0  [1997, 7, 2]
#
#                              birthplace  \
# 0  San Ramon, California, United States
#
#                                             location  \
# 0  (San Ramon, Contra Costa County, California, U...
#
#                              point
# 0  (37.7799273, -121.9780153, 0.0)

# %%
df_var = best_df_ever
#df_var = jackson_df

def point_formatter(row):
    p = df_var.iloc[row].point
    if p == None:
        return None
    p_ns = p[0]
    p_ew = p[1]
    if p_ns > 0:
        p_ns_mod = str(round(p_ns, 4)).replace('.', 'n')
    else:
        p_ns_mod = str(round(-p_ns, 4)).replace('.', 's')
    if p_ew > 0:
        p_ew_mod = str(round(p_ew, 4)).replace('.', 'e')
    else:
        p_ew_mod = str(round(-p_ew, 4)).replace('.', 'w')
    return (p_ns_mod,p_ew_mod)

# %%
point_formatter(0)
# Out:
# ('48n1371', '11e5754')

# %%
best_df_everer = best_df_ever
best_df_everer['point'] = best_df_ever['count'].apply(point_formatter)

# %%
best_df_everer.head(8)
# Out:
#                       name      occupation  count             birthtime  \
# 0           Michael_Haneke  r_philosophers      0         [1942, 1, 23]
# 1             Noam_Chomsky  r_philosophers      1   [1928, 1, 7, 07:00]
# 2             Albert_Camus  r_philosophers      2   [1913, 1, 7, 02:00]
# 3           Mahatma_Gandhi  r_philosophers      3   [1869, 1, 2, 07:08]
# 4    Jean-Jacques_Rousseau  r_philosophers      4  [1712, 1, 28, 10:00]
# 5            Denis_Diderot  r_philosophers      5   [1713, 1, 5, 17:00]
# 6            Immanuel_Kant  r_philosophers      6  [1724, 1, 22, 05:00]
# 7  Johann_Gottfried_Herder  r_philosophers      7  [1744, 1, 25, 23:30]
#
#                                   birthplace  \
# 0                            Munich, Germany
# 1  Philadelphia, Pennsylvania, United States
# 2                           Mondovi, Algeria
# 3                           Porbandar, India
# 4                        Geneva, Switzerland
# 5                            Langres, France
# 6                         Knigsberg, Germany
# 7                          Mohrungen, Poland
#
#                                             location               point
# 0  (München, Bayern, Deutschland, (48.1371079, 11...  (48n1371, 11e5754)
# 1  (Philadelphia, Philadelphia County, Pennsylvan...  (39n9527, 75w1635)
# 2  (Drean, Daïra Drean, El Tarf الطارف, الجزائر, ...   (36n6851, 7e7471)
# 3  (Porbandar, Porbandar Taluka, Porbandar Distri...   (21n6409, 69e611)
# 4     (Genève, Switzerland, (46.2017559, 6.1466014))   (46n2018, 6e1466)
# 5  (Langres, Haute-Marne, Grand Est, France métro...   (47n8656, 5e3314)
# 6                                               None                None
# 7  (Morąg, gmina Morąg, powiat ostródzki, wojewód...    (53n912, 19e928)

# %%
#Method which returns the time offset for a particular timezone.

def get_offset(lat, lng):
    """
    returns a location's time zone offset from UTC in minutes.
    """
    tf = TimezoneFinder()

    today = datetime.now()
    tz_target = timezone(tf.certain_timezone_at(lng=lng, lat=lat))
    today_target = tz_target.localize(today)
    today_utc = utc.localize(today)
    val = (today_utc - today_target).total_seconds()/60
    hr = int(val // 60)
    hr = str(hr).zfill(2)
    mn = int(val - 60 * int(hr))
    mn = str(mn).zfill(2)
    ans = hr + ':' + mn
    return ans


#bergamo = {'lat': 45.69, 'lng': 9.67}
#minute_offset = get_offset(**bergamo)
#print(minute_offset)

# %%
print(get_offset(45.69,9.67))
# Out:
# 02:00

# %%
var_df = best_df_everer
#var_df = jackson_df
##get_offset(lat, lng)
def date_formatter(row):
    old_date = var_df.iloc[row].birthtime
    
    year = str(old_date[0]).zfill(4)
    month = str(old_date[1]).zfill(2)
    day = str(old_date[2]).zfill(2)
    new_date = str(year) + '/' + str(month) + '/' + str(day)
    
    location = var_df.iloc[row].point
    lat = location[0]
    lng = location[1]
    if 'n' in lat:
        lat = lat.replace('n', '.')
    if 's' in lat:
        lat = '-' + (lat.replace('s', '.'))
    if 'e' in lng:
        lng = lng.replace('e', '.')
    if 'w' in lng:
        lng = '-' + (lng.replace('w', '.'))
    offset = get_offset(float(lat), float(lng))
    
    if len(old_date) == 4:
        time = str(old_date[3])
        ans = Datetime(new_date, time, offset)
    else:
        ans = Datetime(new_date, offset)
    return ans

# %%
date_formatter(0)

# %%
var_df = best_df_everer
#var_df = jackson_df

def chart_creator(row):
    if df_var.iloc[row].point == None or df_var.iloc[row].location == None or df_var.iloc[row].birthplace == None or df_var.iloc[row].birthtime == None:
        return None
    d = date_formatter(row)
    #^Remember to use the same df here.
    l = df_var.iloc[row].point
    pos = GeoPos(l[0], l[1])
    try:
        chart = Chart(d, pos)
        return chart
    except:
        None

# %%
#chart_creator(1)
#chart_creator(4).get(const.MOON)
chart_creator(0)

# %% [markdown]
# It works!!!

# %% [markdown]
# Now I'm gonna add a column filled with birthcharts (as objects).

# %%
best_df_everer['chart'] = best_df_ever['count'].apply(chart_creator)

# %%
best_df_everer.head()
# Out:
#                     name      occupation  count             birthtime  \
# 0         Michael_Haneke  r_philosophers      0         [1942, 1, 23]
# 1           Noam_Chomsky  r_philosophers      1   [1928, 1, 7, 07:00]
# 2           Albert_Camus  r_philosophers      2   [1913, 1, 7, 02:00]
# 3         Mahatma_Gandhi  r_philosophers      3   [1869, 1, 2, 07:08]
# 4  Jean-Jacques_Rousseau  r_philosophers      4  [1712, 1, 28, 10:00]
#
#                                   birthplace  \
# 0                            Munich, Germany
# 1  Philadelphia, Pennsylvania, United States
# 2                           Mondovi, Algeria
# 3                           Porbandar, India
# 4                        Geneva, Switzerland
#
#                                             location               point  \
# 0  (München, Bayern, Deutschland, (48.1371079, 11...  (48n1371, 11e5754)
# 1  (Philadelphia, Philadelphia County, Pennsylvan...  (39n9527, 75w1635)
# 2  (Drean, Daïra Drean, El Tarf الطارف, الجزائر, ...   (36n6851, 7e7471)
# 3  (Porbandar, Porbandar Taluka, Porbandar Distri...   (21n6409, 69e611)
# 4     (Genève, Switzerland, (46.2017559, 6.1466014))   (46n2018, 6e1466)
#
#                                          chart
# 0                                         None
# 1  <flatlib.chart.Chart object at 0x617e648d0>
# 2  <flatlib.chart.Chart object at 0x617e7d6a0>
# 3  <flatlib.chart.Chart object at 0x617f0a518>
# 4                                         None

# %% [markdown]
# I need to figure out how many 'None' charts I have.

# %%
#best_df_everer.info(verbose=True)
best_df_everer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 8 columns):
# name          213 non-null object
# occupation    213 non-null object
# count         213 non-null int64
# birthtime     205 non-null object
# birthplace    205 non-null object
# location      183 non-null object
# point         183 non-null object
# chart         136 non-null object
# dtypes: int64(1), object(7)
# memory usage: 13.4+ KB

# %% [markdown]
# I'm thinking at this point I should get rid of any rows that have no chart.

# %%
best_df_everest = best_df_everer

# %%
# df[df['column name'].map(lambda x: str(x)!=".")]
best_df_everest = best_df_everest[best_df_everest['chart'].map(lambda x: x!=None)]

# %%
best_df_everest.head(20)
# Out:
#                        name      occupation  count             birthtime  \
# 1              Noam_Chomsky  r_philosophers      1   [1928, 1, 7, 07:00]
# 2              Albert_Camus  r_philosophers      2   [1913, 1, 7, 02:00]
# 3            Mahatma_Gandhi  r_philosophers      3   [1869, 1, 2, 07:08]
# 5             Denis_Diderot  r_philosophers      5   [1713, 1, 5, 17:00]
# 7   Johann_Gottfried_Herder  r_philosophers      7  [1744, 1, 25, 23:30]
# 8        Soeren_Kierkegaard  r_philosophers      8          [1813, 1, 5]
# 9       Friedrich_Nietzsche  r_philosophers      9  [1844, 1, 15, 10:00]
# 10         Bertrand_Russell  r_philosophers     10  [1872, 1, 18, 17:45]
# 11           Philip_K._Dick  r_philosophers     11  [1928, 1, 16, 12:15]
# 13                Karl_Marx  r_philosophers     13   [1818, 1, 5, 02:00]
# 15              Ernst_Bloch  r_philosophers     15   [1885, 1, 8, 08:00]
# 19           Gilles_Deleuze  r_philosophers     19  [1925, 1, 18, 02:45]
# 20         Friedrich_Engels  r_philosophers     20  [1820, 1, 28, 21:00]
# 21         Ludwig_Feuerbach  r_philosophers     21  [1804, 1, 28, 01:30]
# 22          Michel_Foucault  r_philosophers     22  [1926, 1, 15, 07:30]
# 23              Erich_Fromm  r_philosophers     23  [1900, 1, 23, 19:30]
# 24               David_Hume  r_philosophers     24          [1711, 1, 7]
# 25          Emmanuel_Lasker  r_philosophers     25  [1868, 1, 24, 15:00]
# 26         Maria_Montessori  r_philosophers     26  [1870, 1, 31, 03:30]
# 28           Rudolf_Steiner  r_philosophers     28  [1861, 1, 25, 23:15]
#
#                                    birthplace  \
# 1   Philadelphia, Pennsylvania, United States
# 2                            Mondovi, Algeria
# 3                            Porbandar, India
# 5                             Langres, France
# 7                           Mohrungen, Poland
# 8                         Copenhagen, Denmark
# 9                            Roecken, Germany
# 10            Trelleck, Wales, United Kingdom
# 11           Chicago, Illinois, United States
# 13                             Trier, Germany
# 15                      Ludwigshafen, Germany
# 19                              Paris, France
# 20                         Wuppertal, Germany
# 21                          Landshut, Germany
# 22                           Poitiers, France
# 23                         Frankfurt, Germany
# 24        Edinburgh, Scotland, United Kingdom
# 25                            Berlin, Germany
# 26                         Chiaravalle, Italy
# 28                   Donji Kraljevec, Croatia
#
#                                              location               point  \
# 1   (Philadelphia, Philadelphia County, Pennsylvan...  (39n9527, 75w1635)
# 2   (Drean, Daïra Drean, El Tarf الطارف, الجزائر, ...   (36n6851, 7e7471)
# 3   (Porbandar, Porbandar Taluka, Porbandar Distri...   (21n6409, 69e611)
# 5   (Langres, Haute-Marne, Grand Est, France métro...   (47n8656, 5e3314)
# 7   (Morąg, gmina Morąg, powiat ostródzki, wojewód...    (53n912, 19e928)
# 8   (København, Københavns Kommune, Region Hovedst...  (55n6867, 12e5701)
# 9   (Röcken, Lützen, Burgenlandkreis, Sachsen-Anha...   (51n242, 12e1143)
# 10  (Trelleck Grange, Devauden, Monmouthshire, Wal...   (51n7111, 2w7356)
# 11  (Chicago, Cook County, Illinois, United States...  (41n8756, 87w6244)
# 13  (Trier, Rheinland-Pfalz, 54290, Deutschland, (...   (49n7596, 6e6442)
# 15  (Ludwigshafen am Rhein, Rheinland-Pfalz, 67061...   (49n4704, 8e4382)
# 19  (Paris, Île-de-France, France métropolitaine, ...   (48n8567, 2e3515)
# 20  (Wuppertal, Nordrhein-Westfalen, 42285, Deutsc...     (51n264, 7e178)
# 21  (Landshut, Bayern, Deutschland, (48.536217, 12...  (48n5362, 12e1517)
# 22  (Poitiers, Vienne, Nouvelle-Aquitaine, France ...   (46n5803, 0e3402)
# 23  (Frankfurt am Main, Hessen, Deutschland, (50.1...   (50n1106, 8e6821)
# 24  (Edinburgh, City of Edinburgh, Scotland, EH1 3...   (55n9533, 3w1884)
# 25    (Berlin, Deutschland, (52.5170365, 13.3888599))   (52n517, 13e3889)
# 26  (Chiaravalle, Ancona, Marche, 60033, Italia, (...  (43n6027, 13e3246)
# 28  (Donji Kraljevec, Općina Donji Kraljevec, Međi...   (46n368, 16e6486)
#
#                                           chart
# 1   <flatlib.chart.Chart object at 0x617e648d0>
# 2   <flatlib.chart.Chart object at 0x617e7d6a0>
# 3   <flatlib.chart.Chart object at 0x617f0a518>
# 5   <flatlib.chart.Chart object at 0x617f0ae80>
# 7   <flatlib.chart.Chart object at 0x617f0ab70>
# 8   <flatlib.chart.Chart object at 0x617f2d1d0>
# 9   <flatlib.chart.Chart object at 0x617f2d2e8>
# 10  <flatlib.chart.Chart object at 0x617f3eef0>
# 11  <flatlib.chart.Chart object at 0x617e50320>
# 13  <flatlib.chart.Chart object at 0x617f3ed30>
# 15  <flatlib.chart.Chart object at 0x617e48a90>
# 19  <flatlib.chart.Chart object at 0x617e48780>
# 20  <flatlib.chart.Chart object at 0x617e81ac8>
# 21  <flatlib.chart.Chart object at 0x617e81c88>
# 22  <flatlib.chart.Chart object at 0x617ebe0f0>
# 23  <flatlib.chart.Chart object at 0x617ebe5c0>
# 24  <flatlib.chart.Chart object at 0x617ec1048>
# 25  <flatlib.chart.Chart object at 0x617ec1f60>
# 26  <flatlib.chart.Chart object at 0x617ec54e0>
# 28  <flatlib.chart.Chart object at 0x617ec52b0>

# %% [markdown]
# Sweet, it works!!
#
# I'm just gonna export this as a csv.

# %%
best_df_everest.to_csv('r_philosophers_charted.csv', index=False)
